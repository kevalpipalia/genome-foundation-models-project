# %%
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt 
import pickle
import seaborn as sns

# %%
with open('29552-peft.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
sns.set_theme()
plt.scatter(data.label_ids.tolist(), data.predictions.tolist())
plt.xlabel('original GTEx value')
plt.ylabel('predicted GTEx value')
plt.show()
